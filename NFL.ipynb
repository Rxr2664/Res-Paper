# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
games = pd.read_csv('/kaggle/input/nfl-big-data-bowl-2021/games.csv')
games
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-19-a8439d9d365d> in <cell line: 1>()
# ----> 1 games = pd.read_csv('/kaggle/input/nfl-big-data-bowl-2021/games.csv')
#       2 games
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     948     kwds.update(kwds_defaults)
#     949
# --> 950     return _read(filepath_or_buffer, kwds)
#     951
#     952
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     603
#     604     # Create the parser.
# --> 605     parser = TextFileReader(filepath_or_buffer, **kwds)
#     606
#     607     if chunksize or iterator:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1440
#    1441         self.handles: IOHandles | None = None
# -> 1442         self._engine = self._make_engine(f, self.engine)
#    1443
#    1444     def close(self) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1733                 if "b" not in mode:
#    1734                     mode += "b"
# -> 1735             self.handles = get_handle(
#    1736                 f,
#    1737                 mode,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854         if ioargs.encoding and "b" not in ioargs.mode:
#     855             # Encoding
# --> 856             handle = open(
#     857                 handle,
#     858                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/kaggle/input/nfl-big-data-bowl-2021/games.csv'

# %%
https://raw.githubusercontent.com/ali-ce/datasets/master/NFL/Head%20Injured%20Players.csv

# %%
draftpickadata = pd.read_csv("https://github.com/nflverse/nflverse-data/releases/download/draft_picks/draft_picks.csv")

# %%
¡draftpickadata.columns
# Out:
# Index(['season', 'round', 'pick', 'team', 'gsis_id', 'pfr_player_id',
#        'cfb_player_id', 'pfr_player_name', 'hof', 'position', 'category',
#        'side', 'college', 'age', 'to', 'allpro', 'probowls', 'seasons_started',
#        'w_av', 'car_av', 'dr_av', 'games', 'pass_completions', 'pass_attempts',
#        'pass_yards', 'pass_tds', 'pass_ints', 'rush_atts', 'rush_yards',
#        'rush_tds', 'receptions', 'rec_yards', 'rec_tds', 'def_solo_tackles',
#        'def_ints', 'def_sacks'],
#       dtype='object')

# %%
draftpickadata.groupby(by="team", as_index=True).agg({'pass_yards' : "count"}).head(100)
# Out:
#       pass_yards
# team
# ARI          211
# ATL          317
# BAL          250
# BUF          342
# CAR          195
# CHI          331
# CIN          365
# CLE          305
# DAL          346
# DEN          323
# DET          326
# GNB          365
# HOU          321
# IND          300
# JAX          220
# KAN          323
# LAC           49
# LAR           70
# LVR           29
# MIA          325
# MIN          335
# NOR          290
# NWE          367
# NYG          327
# NYJ          320
# OAK          190
# PHI          331
# PHO           49
# PIT          362
# RAI           89
# RAM          135
# SDG          266
# SEA          317
# SFO          325
# STL          242
# TAM          326
# TEN          213
# WAS          295

# %%
DAL = draftpickadata[ draftpickadata['team'] == "DAL"]

# %%
DAL
# Out:
#        season  round  pick team     gsis_id pfr_player_id    cfb_player_id  \
# 77       1980      3    78  DAL         NaN      RoexBi20       bill-roe-1
# 79       1980      3    80  DAL         NaN      JoneJa01    james-jones-4
# 104      1980      4   105  DAL         NaN      PeteKu20              NaN
# 132      1980      5   133  DAL         NaN      HogeGa00  gary-hogeboom-1
# 161      1980      6   162  DAL         NaN      NewsTi00              NaN
# ...       ...    ...   ...  ...         ...           ...              ...
# 12025    2023      4   129  DAL  00-0038575      FehoVi00  junior-fehoko-1
# 12065    2023      5   169  DAL         NaN      RichAs00  asim-richards-1
# 12074    2023      6   178  DAL  00-0038604      ScotEr00  eric-scott-jr-1
# 12108    2023      6   212  DAL  00-0038622      VaugDe00   deuce-vaughn-1
# 12140    2023      7   244  DAL  00-0038640      BrooJa03   jalen-brooks-2
#
#       pfr_player_name    hof position  ... pass_ints rush_atts rush_yards  \
# 77           Bill Roe  False       LB  ...       0.0       0.0        0.0
# 79        James Jones  False       RB  ...       1.0      84.0      331.0
# 104     Kurt Petersen  False        G  ...       0.0       0.0        0.0
# 132     Gary Hogeboom  False       QB  ...      60.0      83.0      161.0
# 161     Timmy Newsome  False       RB  ...       0.0     342.0     1226.0
# ...               ...    ...      ...  ...       ...       ...        ...
# 12025  Viliami Fehoko  False       DL  ...       NaN       NaN        NaN
# 12065   Asim Richards  False       OL  ...       0.0       0.0        0.0
# 12074      Eric Scott  False       DB  ...       NaN       NaN        NaN
# 12108    Deuce Vaughn  False       RB  ...       0.0      23.0       40.0
# 12140    Jalen Brooks  False       WR  ...       0.0       0.0        0.0
#
#        rush_tds  receptions  rec_yards  rec_tds  def_solo_tackles  def_ints  \
# 77          0.0         0.0        0.0      0.0               NaN       NaN
# 79          1.0        42.0      312.0      1.0               NaN       NaN
# 104         0.0         0.0        0.0      0.0               NaN       NaN
# 132         4.0         0.0        0.0      0.0               NaN       NaN
# 161        19.0       212.0     1966.0     11.0               NaN       NaN
# ...         ...         ...        ...      ...               ...       ...
# 12025       NaN         NaN        NaN      NaN               NaN       NaN
# 12065       0.0         0.0        0.0      0.0               NaN       NaN
# 12074       NaN         NaN        NaN      NaN               NaN       NaN
# 12108       0.0         7.0       40.0      0.0               NaN       NaN
# 12140       0.0         6.0       64.0      0.0               NaN       NaN
#
#        def_sacks
# 77           NaN
# 79           NaN
# 104          NaN
# 132          NaN
# 161          NaN
# ...          ...
# 12025        NaN
# 12065        NaN
# 12074        NaN
# 12108        NaN
# 12140        NaN
#
# [430 rows x 36 columns]

# %%
plt.bar(x=DAL['season'], height=DAL['pass_yards'])
plt.title("Has the NFL become more pass freindly since 1980?")
plt.xlabel("season")
plt.ylabel("Number of Passing Yards")
# Out:
# Text(0, 0.5, 'Number of Passing Yards')

# %%
pass_yards = DAL.columns.get_loc('pass_yards')

# %%
pass_yards
# Out:
# 24
