# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
injuries = pd.read_csv("https://github.com/nflverse/nflverse-data/releases/download/injuries/injuries_2023.csv")

# %%
injuries
# Out:
#       season game_type team  week     gsis_id position       full_name  \
# 0       2023       REG  ARI     1  00-0034473       LB  Dennis Gardeck
# 1       2023       REG  ARI     1  00-0029316        T  Kelvin Beachum
# 2       2023       REG  ARI     1  00-0035662       WR  Marquise Brown
# 3       2023       REG  ARI     1  00-0030061       TE       Zach Ertz
# 4       2023       REG  ATL     1  00-0033858       TE     Jonnu Smith
# ...      ...       ...  ...   ...         ...      ...             ...
# 5594    2023        WC   TB    19  00-0036406        T   Tristan Wirfs
# 5595    2023        WC   TB    19  00-0037627       DT     Mike Greene
# 5596    2023        WC   TB    19  00-0036643       LB      K.J. Britt
# 5597    2023        WC   TB    19  00-0039051       CB      Josh Hayes
# 5598    2023        WC   TB    19  00-0034855       QB  Baker Mayfield
#
#      first_name last_name report_primary_injury report_secondary_injury  \
# 0        Dennis   Gardeck                   NaN                     NaN
# 1        Kelvin   Beachum                  Hand                     NaN
# 2      Marquise     Brown             Hamstring                     NaN
# 3          Zach      Ertz                  Knee                     NaN
# 4         Jonnu     Smith                   NaN                     NaN
# ...         ...       ...                   ...                     ...
# 5594    Tristan     Wirfs                   NaN                     NaN
# 5595       Mike    Greene                  Calf                     NaN
# 5596       K.J.     Britt                  Calf                     NaN
# 5597       Josh     Hayes             Quadricep                    Knee
# 5598      Baker  Mayfield                 Ankle                    Ribs
#
#      report_status              practice_primary_injury  \
# 0              NaN                                 Knee
# 1              Out                                 Hand
# 2     Questionable                            Hamstring
# 3     Questionable                                 Knee
# 4              NaN  Not injury related - resting player
# ...            ...                                  ...
# 5594           NaN                              Illness
# 5595           Out                                 Calf
# 5596  Questionable                                 Calf
# 5597  Questionable                            Quadricep
# 5598  Questionable                                Ankle
#
#      practice_secondary_injury                    practice_status  \
# 0                          NaN     Full Participation in Practice
# 1                          NaN    Did Not Participate In Practice
# 2                          NaN  Limited Participation in Practice
# 3                          NaN  Limited Participation in Practice
# 4                          NaN    Did Not Participate In Practice
# ...                        ...                                ...
# 5594                       NaN     Full Participation in Practice
# 5595                       NaN     Full Participation in Practice
# 5596                       NaN     Full Participation in Practice
# 5597                      Knee  Limited Participation in Practice
# 5598                      Ribs  Limited Participation in Practice
#
#              date_modified
# 0     2023-09-08T18:49:43Z
# 1     2023-09-08T18:50:25Z
# 2     2023-09-08T18:50:02Z
# 3     2023-09-08T18:50:02Z
# 4     2023-09-06T20:54:47Z
# ...                    ...
# 5594  2024-01-13T20:44:20Z
# 5595  2024-01-13T20:45:00Z
# 5596  2024-01-13T20:44:49Z
# 5597  2024-01-13T20:44:49Z
# 5598  2024-01-13T20:44:49Z
#
# [5599 rows x 16 columns]
